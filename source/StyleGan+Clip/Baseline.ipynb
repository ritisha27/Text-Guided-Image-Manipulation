# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
# %cd base
os.getcwd()
# Out:
# /home2/bagler/content/ImgMan/base
# '/home2/bagler/content/ImgMan/base'

# %%
from main_script import main

# %%
model = 'styleganinv_ffhq256'
text = 'the girl is wearing silver earrings'
clip_loss_wt = 2.0
lr = 0.01
iterations = 130
img_path = "./examples/kid.png"

# %%
main(model, text, lr, iterations, clip_loss_wt, img_path)
# Out:
# [2023-03-10 05:23:30,785][INFO] Build network for module `generator` in model `styleganinv_ffhq256`.
# [2023-03-10 05:23:31,016][INFO] Loading pytorch weights from `models/pretrain/styleganinv_ffhq256_generator.pth`.
# [2023-03-10 05:23:31,100][INFO] Successfully loaded!
# [2023-03-10 05:23:33,104][INFO] Current `lod` is 0.0.
# [2023-03-10 05:23:33,106][INFO] Build network for module `encoder` in model `styleganinv_ffhq256`.
# [2023-03-10 05:23:34,033][INFO] Loading pytorch weights from `models/pretrain/styleganinv_ffhq256_encoder.pth`.
# [2023-03-10 05:23:34,596][INFO] Successfully loaded!
# loss_pix: 0.031, loss_feat: 2886.401, loss_reg: 0.018, loss_clip: 0.623, loss: 1

# %%
org_img = cv2.imread('results/inversion/test/kid_org.png')
invrt_img = cv2.imread('results/inversion/test/kid_encode.png')
man_img = cv2.imread('results/inversion/test/kid_invert.png')
result = np.hstack([org_img, invrt_img, man_img])

# %%
# %matplotlib inline
plt.figure(figsize=(20,20))
plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))
plt.show()
